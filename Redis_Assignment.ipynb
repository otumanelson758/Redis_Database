# %% [markdown]
# #Nelson Redis-Introduction to Redis Project

# %% [markdown]
# #Instructions
# #Problem Statement
#
# Your task for this project will be to write
#
# *   a Python script that imports data from a dummy
# *  CSV file into a remote Redis database
# The dummy CSV file can contain any data that you want but the same data must be
# imported into the remote Redis database. Once you do that, you'll then be required to
# write Python code that retrieves, updates, and deletes the same data from the Redis
# database. Do note that while retrieving the data from Redis, you will be required to store
# it in a Pandas data frame.
#
# For the Remote Redis database, you can create a Redis Cloud account on Redis and
# sign up for the free fixed plan that doesn't require any payment. Once you've done that,
# you'll then create a database that you'll connect to remotely. To connect to Redis you will
# need to go through the official Redis documentation and/or use other reliable sources.

# %%
# !pip install redis
#We install redis application
# Out:
# Collecting redis
#   Downloading redis-4.1.4-py3-none-any.whl (175 kB)
#      |████████████████████████████████| 175 kB 3.1 MB/s
# Collecting deprecated>=1.2.3
#   Downloading Deprecated-1.2.13-py2.py3-none-any.whl (9.6 kB)
# Requirement already satisfied: packaging>=20.4 in /usr/local/lib/python3.7/dist-packages (from redis) (21.3)
# Requirement already satisfied: importlib-metadata>=1.0 in /usr/local/lib/python3.7/dist-packages (from redis) (4.11.2)
# Requirement already satisfied: wrapt<2,>=1.10 in /usr/local/lib/python3.7/dist-packages (from deprecated>=1.2.3->redis) (1.13.3)
# Requirement already satisfied: typing-extensions>=3.6.4 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=1.0->redis) (3.10.0.2)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=1.0->redis) (3.7.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=20.4->redis) (3.0.7)
# Installing collected packages: deprecated, redis
# Successfully installed deprecated-1.2.13 redis-4.1.4

# %%
# Connect to Redis
import redis
#Redis by default consists of 16 logical databases. Starting from 0 index and ending with 15
r = redis.StrictRedis(
    host='redis-15769.c84.us-east-1-2.ec2.cloud.redislabs.com',
    port=15769,
    password='e5ZNNfSWRr3NRqvOuOaELqgFsyq8vXpD',
    db=0,#In redis cluster we can't used select command and only support 0 database
    decode_responses=True
)

# %%
#We upload the dummmy file to redis server remotely
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-a89667ce-15b1-49d3-a6f5-9d48b3d3aee5" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-a89667ce-15b1-49d3-a6f5-9d48b3d3aee5">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving dummy.csv to dummy.csv
# {'dummy.csv': b'Article_Title,Article_Link,Date,Topic\r\n"African, Asian countries to rally behind Afghanistan in crucial meet",https://nation.africa//kenya/news/africa/african-asian-countries-to-rally-behind-afghanistan-in-crucial-meet-3651120,12/14/2021,Terrorism\r\nBoni villagers demand a piece of operation budget,https://nation.africa//kenya/counties/lamu/why-boni-villagers-want-a-piece-of-forest-operation-budget-3652200,12/14/2021,Terrorism\r\nSofia cartels doing roaring business in Western ,https://nation.africa//kenya/counties/busia/sofia-cartels-doing-roaring-business-in-western-3651980,12/14/2021,Smuggling\r\nShabaab attempt to abduct worshippers in Wajir,https://nation.africa//kenya/counties/wajir/shabaab-attempt-to-abduct-worshippers-in-wajir-3651720,12/14/2021,Terrorism\r\n"Srinagar: Three dead, 11 injured in militant attack on ...",https://www.the-star.co.ke//news/world/2021-12-14-srinagar-three-dead-11-injured-in-militant-attack-on-police-bus/,12/14/2021,Terrorism\r\nAdored and endangered: The complex world of the Japanese eel,https://www.the-star.co.ke//news/world/2021-12-14-adored-and-endangered-the-complex-world-of-the-japanese-eel
header = next(f)

# %%
#we need to reconnect back to redis
r = redis.Redis(
    host='redis-15769.c84.us-east-1-2.ec2.cloud.redislabs.com',
    port=15769, 
    password='e5ZNNfSWRr3NRqvOuOaELqgFsyq8vXpD',
    db=0,#In redis cluster we can't used select command and only support 0 database
    decode_responses=True)

doclist= []
#iterate through the doc
for row in f:
  doc = dict(zip(header, row))
  doclist.append(doc)
#import the json library
import json

key = "dummy"

r.set(key, json.dumps(doclist))
data_frame = json.loads(r.get(key))
print(data_frame)
# Out:
# []

# %%
#Task we need to store the data in pandas 
#import the pandas series library
import pandas as pd

#create pandas dataframe and assisgn to data_redis
data_redis = pd.DataFrame()
#loop through the data_frame 
for item in data_frame:
  data_redis = data_redis.append(item, ignore_index=True)

print(data_redis.shape)
# we will have to upload the file

from google.colab import files
files.upload()
# Out:
# (0, 0)
#      <input type="file" id="files-06ebe546-1d45-4533-8a73-650043b2e286" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-06ebe546-1d45-4533-8a73-650043b2e286">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# {}

# %%
#we need to upload the file to redis server
import csv

f = csv.reader(open("dummy_update.csv",encoding='ISO 8859-1'))
header = next(f)
#we reconnect back to Redis through the host,port,password,db
r = redis.Redis(
    host='redis-15769.c84.us-east-1-2.ec2.cloud.redislabs.com',
    port=15769, 
    password='e5ZNNfSWRr3NRqvOuOaELqgFsyq8vXpD',
    db=0,#In redis cluster we can't used select command and only support 0 database
    decode_responses=True)

doclist_update= []

for row in f:
  doc = dict(zip(header, row))
  doclist_update.append(doc)

# %% [markdown]
#  We will need to import json
#  Get file data save in pandas dataframes

# %%
import json

key = "dummy"

updated_list = doclist_update + doclist

r.set(key, json.dumps(updated_list))

# get the data save in pandas data frame

data_frame = json.loads(r.get(key))
print(data_frame)
#we import pandas as pd library
import pandas as pd

output = pd.DataFrame()
#iterate through using for loop.
for item in data_frame:
  output = output.append(item, ignore_index=True)

output.shape

#we now delete the data that we created ealier redis flush db

r.flushdb()

# confirm if done successfully
print(r.keys())
# Out:
# [{'Article_Title': 'Treasury disowns\xa0Sh785m wired to\xa0CBK in Germany', 'Article_Link': 'https://www.businessdailyafrica.com//bd/news/treasury-disowns-sh785m-wired-to-cbk-in-germany-3703496', 'Date': '02/03/2022', 'Topic': 'Money-Laundering'}, {'Article_Title': 'DR NJENGA: Tread carefully when dealing with recluses', 'Article_Link': 'https://www.businessdailyafrica.com//bd/lifestyle/health-fitness/tread-carefully-when-dealing-with-recluses-3701930', 'Date': '02/03/2022', 'Topic': 'Terrorism'}, {'Article_Title': 'Treasury red tape delays reforms to ease Sh55bn unclaimed assets access', 'Article_Link': 'https://www.businessdailyafrica.com//bd/data-hub/treasury-red-tape-delays-ease-sh55bn-unclaimed-assets-access-3699694', 'Date': '02/03/2022', 'Topic': 'Money-Laundering'}, {'Article_Title': ' Burkina Faso a lesson on how violent extremism can undermine State and social institutions\xa0\xa0 ', 